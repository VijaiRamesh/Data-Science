# %% [markdown]
# <img src="https://www.hopelearning.net/wp-content/uploads/2020/09/LOGO.png" alt="fishy" class="bg-primary" width="50px">

# %% [markdown]
# # Inference or Conclusion needed for every question

# %% [markdown]
# ## ** Download the dataset from <a href="https://drive.google.com/file/d/1hiR9XbTjMsNk_uA025w5nrw5LTBUDCEC/view?usp=sharing">here(Click Here)</a>

# %% [markdown]
# ## 1)Replace the NaN values with correct value. And justify why you have chosen the same.

# %%
import pandas as pd
import seaborn as sns

# %%
dataset=pd.read_csv("Placement_Data_Full_Class (1).csv")

# %%
dataset=dataset.drop(["sl_no"],axis=1)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# ### Who are get Salary as NaN they are Not placed . so we replace NaN as 0

# %%
dataset["salary"]=dataset["salary"].fillna(0)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# ## 2)How many of them are not placed?

# %% [markdown]
# ### 67 of them not placed

# %%
dataset.groupby(["status"]).size()
# Out:
# status
# Not Placed     67
# Placed        148
# dtype: int64

# %% [markdown]
# ## 3)Find the reason for non placement from the dataset?

# %% [markdown]
# degree_t Comm&Mgmt students not fit for Mkt&HR specialisation
#
# Also Workex students are placed

# %%
dataset.groupby(["salary","degree_p","degree_t","workex","etest_p","specialisation","mba_p"]).size()
# Out:
# salary    degree_p  degree_t   workex  etest_p  specialisation  mba_p
# 0.0       50.00     Comm&Mgmt  No      76.00    Mkt&HR          54.96    1
#           50.20     Comm&Mgmt  Yes     76.00    Mkt&Fin         65.33    1
#           50.80     Comm&Mgmt  No      67.00    Mkt&HR          62.79    1
#           52.00     Others     No      65.00    Mkt&HR          56.11    1
#                                        68.44    Mkt&HR          62.77    1
#                                                                         ..
# 500000.0  64.27     Sci&Tech   Yes     64.00    Mkt&Fin         66.23    1
#           65.00     Sci&Tech   Yes     69.00    Mkt&Fin         57.65    1
# 650000.0  79.00     Comm&Mgmt  Yes     89.00    Mkt&Fin         70.81    1
# 690000.0  58.00     Sci&Tech   Yes     56.00    Mkt&Fin         61.30    1
# 940000.0  64.60     Comm&Mgmt  Yes     82.66    Mkt&Fin         64.34    1
# Length: 215, dtype: int64

# %% [markdown]
# ## 4)What kind of relation between salary and mba_p

# %%
dataset[["salary","mba_p"]].corr()
# Out:
#           salary     mba_p
# salary  1.000000  0.139823
# mba_p   0.139823  1.000000

# %% [markdown]
# ## 5)Which specialization is getting minimum salary?

# %% [markdown]
# ### Both specialization is getting minimum salary(0)

# %%
dataset.groupby("specialisation").agg({"salary":"min"})
# Out:
#                 salary
# specialisation
# Mkt&Fin            0.0
# Mkt&HR             0.0

# %% [markdown]
# ## 6)How many of them getting above 500000 salary?

# %% [markdown]
# ### 6 of them getting above 500000 salary in Mkt&Fin specialisation

# %%
len(dataset[dataset["salary"]>=500000])
# Out:
# 6

# %% [markdown]
# ## 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %% [markdown]
# ## Hypothesis Testing:
#
# Null Hypothesis:There is no similarity between given statement
#
# Alternate: There is a similarity
#
# p<0.05-->True-->Reject null
#
# p value 4.672547689133573e-21
#
# 4.672547689133573e-21<0.05 condition True
#
# Due to condition True we are able to reject null values.
#
# so we can take Alternative hypothesis
#
# There is similarity between etest_p and mba_p parameters

# %%
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"],dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
4.672547689133573e-21<0.05
# Out:
# True

# %% [markdown]
# ## 8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary  at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
dataset.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status    salary
# 0     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# ## Hypothesis Testing:
# Null Hypothesis:There is no similarity between given statement
#
# Alternate: There is a similarity
#
# p<0.05-->True-->Reject null
#
# p value 0.007897969943471179
#
# 0.007897969943471179<0.05 condition True
#
# Due to condition True we are able to reject null values.
#
# so we can take Alternative hypothesis
#
# There is similarity between Sci&Tech and Mkt&HR salary

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
etest_p = dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
mba_p = dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]
ttest_ind(etest_p, mba_p)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %%
0.007897969943471179<0.05
# Out:
# True

# %% [markdown]
# ## 9)Convert the normal distribution to standard normal distribution for salary column

# %% [markdown]
# # Normal distribution

# %%
sns.distplot(dataset["salary"])

# %% [markdown]
# ### Converting Normal Distribution to Standard Normal Distribution

# %%
mean=dataset["salary"].mean()
std=dataset["salary"].std()

values=[i for i in dataset["salary"]]

z_score=[((j-mean)/std) for j in values]

sns.distplot(z_score,kde=True)

sum(z_score)/len(z_score)
# Out:
# -8.881784197001253e-17

# %% [markdown]
# ## 10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# Mean=198702.326, Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974901
# 0.0005973310593974901

# %% [markdown]
# ## 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %% [markdown]
# ## Hypothesis Testing:
# Null Hypothesis:There is no similarity between given statement
#
# Alternate: There is a similarity
#
# p<0.05-->True-->Reject null
#
# p value 5.517920600505392e-06
#
# 5.517920600505392e-06<0.05 condition True
#
# Due to condition True we are able to reject null values.
#
# so we can take Alternative hypothesis
#
# There is similarity between etest_p and mba_p parameters

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
etest_p = dataset[dataset["degree_t"]=="Sci&Tech"]["etest_p"]
mba_p = dataset[dataset["degree_t"]=="Sci&Tech"]["mba_p"]
ttest_rel(etest_p, mba_p)
# Out:
# Ttest_relResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06)

# %%
5.517920600505392e-06<0.05
# Out:
# True

# %% [markdown]
# ## 12)Which parameter is highly correlated with salary?

# %% [markdown]
# ### ssc_p is highly correlated with salary (0.538090)

# %%
dataset.corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# ## 13) plot  any useful graph and explain it.

# %% [markdown]
# ## It helps to find correlation between the columns using graph

# %%
sns.pairplot(dataset)

# %% [markdown]
# submit as "YOURNAME_InferentialAnalysis.ipynb"  to admin@hopelearning.net

# %% [markdown]
# www.hopelearning.net
